# %%
import numpy as np
import matplotlib.pyplot as plt

# Definicja sygnału w dziedzinie częstotliwości
X_mu = np.array([6, 2, 4, 3, 4, 5, 0, 0, 0, 0], dtype=complex)
N = len(X_mu)

# Macierz Fouriera W
k = np.arange(N).reshape(N, 1)
mu = np.arange(N).reshape(1, N)
W = np.exp(2j * np.pi * k * mu / N)

# Obliczenie IDFT w notacji macierzowej
x_k = (1/N) * W @ X_mu

# Wizualizacja sygnału
plt.stem(np.real(x_k))
plt.xlabel('Numer harm,onicznej k')
plt.ylabel('Próbka sygnału x[k]')
plt.title('Syntezowany sygnał czasowy')
plt.grid()
plt.show()

# Wyświetlanie wyników
print("Macierz Fouriera W:")
print(np.round(W, decimals=4))
# Out:
# Macierz Fouriera W:
# [[ 1.   +0.j      1.   +0.j      1.   +0.j      1.   +0.j
#    1.   +0.j      1.   +0.j      1.   +0.j      1.   +0.j
#    1.   +0.j      1.   +0.j    ]
#  [ 1.   +0.j      0.809+0.5878j  0.309+0.9511j -0.309+0.9511j
#   -0.809+0.5878j -1.   +0.j     -0.809-0.5878j -0.309-0.9511j
#    0.309-0.9511j  0.809-0.5878j]
#  [ 1.   +0.j      0.309+0.9511j -0.809+0.5878j -0.809-0.5878j
#    0.309-0.9511j  1.   -0.j      0.309+0.9511j -0.809+0.5878j
#   -0.809-0.5878j  0.309-0.9511j]
#  [ 1.   +0.j     -0.309+0.9511j -0.809-0.5878j  0.809-0.5878j
#    0.309+0.9511j -1.   +0.j      0.309-0.9511j  0.809+0.5878j
#   -0.809+0.5878j -0.309-0.9511j]
#  [ 1.   +0.j     -0.809+0.5878j  0.309-0.9511j  0.309+0.9511j
#   -0.809-0.5878j  1.   -0.j     -0.809+0.5878j  0.309-0.9511j
#    0.309+0.9511j -0.809-0.5878j]
#  [ 1.   +0.j     -1.   +0.j      1.   -0.j     -1.   +0.j
#    1.   -0.j     -1.   -0.j      1.   -0.j     -1.   +0.j
#    1.   -0.j     -1.   -0.j    ]
# ...
